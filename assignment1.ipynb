# %% [markdown]
# # Question 1
#
# THE DATA TYPES ARE:

# %% [markdown]
# 5 – Integer Data type
# 5.0 – Float Data type
# 5>1 – Relational Data type
# ‘5’ – Character Data type
# 5*2 – Arithmetic operator
# ‘5’*2 – Arithmetic operator
# 5/2 – Arithmetic operator
# 5%2 – Arithmetic operator
# {5,2,1} – String Data type
# 5=3 – Assignment Operator
# Pi(the number) – Integer Data type

# %% [markdown]
# # Question 2a
#
# FIND THE NUMBER OF LETTERS IN A GIVEN STRING

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp1
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             string str;
#             Console.WriteLine("Enter your string");
#             str=Console.ReadLine();
#             int l,count = 0;
#             l = str.Length;
#             for (int i = 0; i < l; i++)
#             {
#                 if (str[i] != 0)
#                     count++;
#             }
#             Console.Write("The total numbers of letters in the given string is = " +count);
#             Console.ReadLine();
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
#
# ![2a.JPG](attachment:2a.JPG)

# %% [markdown]
# # Question 2b
#
# FIND THE SUBSTRING IN A GIVEN STRNG

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp3
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             Console.WriteLine("Enter the String");
#             string str1 = Console.ReadLine();
#             Console.WriteLine("Enter the Substring");
#             string str2 = Console.ReadLine();
#
#            bool m = str1.Contains(str2);
#             if (m)
#                 Console.WriteLine("The substring is present in the string");
#             else
#                 Console.WriteLine("The substring is not present in the given string");
#             Console.ReadLine();
#         }
#     }
# }

# %% [markdown]
# ![2b.JPG](attachment:2b.JPG)

# %% [markdown]
# # Question 2c
#
# FIND THE LONGEST STRING

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp4
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             string a = "Supercalifragilisticexpalidocious", b = "Honorificabilitudinitatibus",
#                        c = "bababadalgharaghtakamminc";
#             int alength = a.Length;
#             int blength = b.Length;
#             int clength = c.Length;
#             {
#                 if ((alength > blength) && (alength > clength))
#                     Console.WriteLine("Longest String : string a " );
#
#                 else
#                 {
#                     if ((blength > alength) && (blength > clength))
#                         Console.WriteLine("Longest string is : string b" );
#                     else
#                         Console.WriteLine("Longest String : string c");
#                 }
#                 Console.ReadLine();
#             }
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
# ![2c.JPG](attachment:2c.JPG)

# %% [markdown]
# # Question 2d
#
# FIRST COMPOSERS IN THE DICTONARY

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp6
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             string[] composers = { "Berloiz", "Borodin", "Brain", "Bartok","Bellini",
#                 "Bxtehude", "Bernstein" };
#             Array.Sort(composers);
#             Console.WriteLine("The order of the composers in the dictionary is : ");
#             foreach (string composer in composers)
#                 Console.WriteLine(composer);
#             Console.ReadLine();
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
# ![2d.JPG](attachment:2d.JPG)

# %% [markdown]
# # Question 3
#
# FIND THE AREA OF TRIANGLE

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp7
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             Console.WriteLine("Enter the length of side1 :");
#             double a = Convert.ToDouble(Console.ReadLine());
#             Console.WriteLine("Enter the length of side2 :");
#             double b = Convert.ToDouble(Console.ReadLine());
#             Console.WriteLine("Enter the length of side3 :");
#             double c = Convert.ToDouble(Console.ReadLine());
#             {
#                 double s = ((a + b + c)/ 2);
#                 double A = Math.Sqrt(s * (s - a) * (s - b) * (s - c));
#                 Console.WriteLine("Area of the triangle :" + A);
#                 Console.ReadKey();
#             }
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# # Question 4
#
# SEPERATE THE ODD AND EVEN NUMBERS

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp8
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             int i, j = 0, k = 0, n;
#             Console.WriteLine("Enter the number of elements in the array :");
#             n = Convert.ToInt32(Console.ReadLine());
#             int[] a = new int[n];
#             Console.WriteLine("Input{0} elements in the array :");
#             for (i = 0; i < n; i++)
#             {
#                 Console.WriteLine("element-{0}:", i);
#                 a[i] = Convert.ToInt32(Console.ReadLine());
#             }
#             for (i = 0; i < n; i++)
#             {
#                 if (a[i] % 2 == 0)
#                 {
#                     j = j;
#                     j++;
#                 }
#                 else
#                 {
#                     k = k;
#                     k++;
#                 }
#             }
#             Console.WriteLine("\n The even numbers are : \n ");
#             for (i = 0; i < j; i++)
#             {
#                 Console.Write("{0}\n",a[j]);
#             }
#             Console.WriteLine("\n The odd elements are : \n ");
#             for (i = 0; i < k; i++)
#             {
#                 Console.Write("{0}\n", a[k]);
#             }
#             Console.ReadLine();
#         }
#     }
#  }

# %% [markdown]
# OUTPUT:
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# # Queation 5a
#
# FUNCTION WHICH RETURNS TRUE OR FALSE

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp9
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#
#             int x1 = 0, y1 = 0, x2 = 2, y2 = 3;
#             int x = -1, y = -1;
#             {
#                 if (x > x1 && x < x2 && y > y1 && y < y2)
#                 {
#                     Console.WriteLine("inside (1,1,0,0,2,3)");
#                     Console.Write("true");
#                 }
#                 else
#                 {
#                     Console.WriteLine("inside (-1,-1,0,0,2,3)");
#                     Console.Write("false");
#                 }
#             }
#             Console.ReadLine();
#
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
# ![5a.JPG](attachment:5a.JPG)

# %% [markdown]
# # Question 5b
#
# WRITING INSIDE() FUNCTION TO FIND THE POINT

# %% [markdown]
# PROGRAM:
#
# namespace ConsoleApp10
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             double x1 = 0.3, y1 = 0.5, x2 = 1.1, y2 = 0.7;
#             int x = 1, y = 1;
#             double x3 = 0.5, y3 = 0.2, x4 = 1.1, y4 = 2;
#             {
#                 if (x > x1 && x < x2 && y > y1 && y < y2)
#                 {
#                     Console.WriteLine("inside (1,1,0.3,0.5,1.1,0.7)");
#                     Console.Write("true");
#                 }
#                 else
#                 {
#                     Console.WriteLine("inside (1,1,0.3,0.5,1.1,0.7)");
#                     Console.Write("false");
#                 }
#             }
#             Console.ReadLine();
#             {
#                 if (x > x3 && x < x4 && y > y3 && y < y4)
#                 {
#                     Console.WriteLine("inside (1,1,0.5,0.2,1.1,2)");
#                     Console.Write("true");
#                 }
#                 else
#                 {
#                     Console.WriteLine("inside (1,1,0.5,0.2,1.1,2)");
#                     Console.Write("false");
#                 }
#             }
#             Console.ReadLine();
#         }
#     }
# }

# %% [markdown]
# OUTPUT:
# ![5b.JPG](attachment:5b.JPG)

# %% [markdown]
# # Question 6
#
# TURN A WORD INTO PIG-LATIN

# %% [markdown]
# PROGRAM:
#
# list = input ("Enetr the string to be converted to piglatin : ");
# vowels = ("a","e","i","o","u","A","E","I","O","U")
# x = list.split()
# for i in list.split():
#     if i[0] in 'vowels':
#         print ("The word is starting with vowel")
#         print (i+"way")
#     else:
#         print ("The word is starting with consonant")
#         print (i[1:]+i[0]+"ay")

# %% [markdown]
# OUTPUT:
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# # Question 7
#
# bldcount() FUNCTION

# %% [markdown]
# PROGRAM:
#
# def bldcount(bloodtype):
#     infile = open(bloodtype, 'r')
#     content = infile.read()
#     infile.close()
#     content = content.split()
#     bloodtype = ['A','B','AB','O','OO']
#     for i in bloodtype:
#         if content.count(i)==0:
#             print ('There are no patients of blood type', i+'.')
#         else:
#             if content.count(i)==1:
#                 print ('There is 1 patient of blood type', i+'.')
#             else:
#                 print ('There are', content.count(i),'patients of blood type', i+'.')
#
# bldcount('bloodtype.txt')

# %% [markdown]
# OUTPUT:
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# # Question 8
#
# curconv() FUNCTION

# %% [markdown]
# PROGRAM:
#
# def concurv(currencies):
#     infile = open(currencies, 'r')
#     content = infile.read()
#     infile.close()
#     from_country = input("from country:").upper()
#     to_country = input("to country:").upper()
#     amount = int (input("amount:"))
#     print (from_country," to ", to_country, amount)
#     result = c.convert(from_currency,to_currency,amount)
#     print (result)
#
# concurv('currencies.txt')

# %% [markdown]
# OUTPUT:
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# # Question 9
#
# TYPES OF EXCEPTION(ERRORS)

# %% [markdown]
# a.	Syntax error
# b.	Index error
# c.	Index error
# d.	Syntax error
# e.	Name error

# %% [markdown]
# # Question 10
#
# frequencies() FUNCTION

# %% [markdown]
# PROGRAM:
#
# test_str = "the quick red fox got bored and went home"
# all_freq = {}
# for i in test_str:
#  if i in all_freq:
#     all_freq[i] += 1
#  else:
#     all_freq[i] = 1
# print ("Count of all characters  is :\n " +  str(all_freq))

# %% [markdown]
# OUTPUT:
# ![10.JPG](attachment:10.JPG)
